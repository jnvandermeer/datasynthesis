# %%
import logging
logging.basicConfig(level=logging.CRITICAL)

# %%
import importlib
import datasynthesis
importlib.reload(datasynthesis)
from datasynthesis import DataSynthesis

# %%
ds = DataSynthesis()

ds.load('5_Cognitive/1_BART/1_heat_cognitive_bart_summary_long.csv',
        participantid='participant_id',
        data='value',
        type='variable',
        unit='unit',
        cols_to_keep=None,
        session='period',
        time_value=None,
        time_unit=None,
)

ds.checkit()
# Out:
# There are 27 participants in this data sheet
# 	H001
# 	H002
# 	H003
# 	H004
# 	H005
# 	H006
# 	H007
# 	H008
# 	H009
# 	H010
# 	H011
# 	H012
# 	H013
# 	H014
# 	H015
# 	H016
# 	H017
# 	H018
# 	H019
# 	H020
# 	H021
# 	H022
# 	H023
# 	H024
# 	H025
# 	H026
# 	H105
# There are 4 sessions in this data sheet
# 	Baseline
# 	Pre2h
# 	PostStress
# 	Post24h
# There are the following variables and units:
# 	adjustedaveragepumpcount -- in units: count
# 	adjustedaveragepumpcount_10 -- in units: count
# 	adjustedaveragepumpcount_20 -- in units: count
# 	adjustedaveragepumpcount_30 -- in units: count
# 	adjustedtotalpumpcount -- in units: count
# 	adjustedtotalpumpcount_10 -- in units: count
# 	adjustedtotalpumpcount_20 -- in units: count
# 	adjustedtotalpumpcount_30 -- in units: count
# 	averagepumpcount -- in units: count
# 	averagepumpcount_10 -- in units: count
# 	averagepumpcount_20 -- in units: count
# 	averagepumpcount_30 -- in units: count
# 	ballooncount -- in units: count
# ...

# %%
ds.synthesize()
# Out:
# We will synthesize 3132 entries of data
# Each entry may contain numerous time points
# 100%|█████████████████████████████████████| 3132/3132 [00:01<00:00, 2157.22it/s]

# %%
ds.export()
# Out:
# Written: /data1/projects/Heat/synthesized/1_heat_cognitive_bart_summary_long_synthesized.csv

# %%
ds = DataSynthesis()

ds.load('/data1/projects/Heat/5_Cognitive/2_PGNG/2_heat_cognitive_pgng_summary_long.csv',
        participantid='participant_id',
        data='value',
        type='variable',
        unit='unit',
        cols_to_keep=None,
        session='period',
        time_value=None,
        time_unit=None,
)

ds.checkit()
# Out:
# There are 27 participants in this data sheet
# 	H001
# 	H002
# 	H003
# 	H004
# 	H005
# 	H006
# 	H007
# 	H008
# 	H009
# 	H010
# 	H011
# 	H012
# 	H013
# 	H014
# 	H015
# 	H016
# 	H017
# 	H018
# 	H019
# 	H020
# 	H021
# 	H022
# 	H023
# 	H024
# 	H025
# 	H026
# 	H105
# There are 5 sessions in this data sheet
# 	Baseline
# 	Pre2h
# 	PostStress1
# 	PostStress2
# 	Post24h
# There are the following variables and units:
# 	PCIT_2TB -- in units: percent
# 	PCIT_3TB -- in units: percent
# 	PCTT_2TB -- in units: percent
# 	PCTT_3TA -- in units: percent
# 	PCTT_3TB -- in units: percent
# 	PCTT_overall -- in units: percent
# 	RTT_2TB -- in units: ms
# 	RTT_3TA -- in units: ms
# 	RTT_3TB -- in units: ms
# 	RTT_overall -- in units: ms
# 	pctCommissionError_2TB -- in units: percent
# 	pctCommissionError_3TA -- in units: percent
# 	pctCommissionError_3TB -- in units: percent
# 	pctCommissionError_overall -- in units: percent
# 	pctCorrect_2TB -- in units: percent
# 	pctCorrect_3TA -- in units: percent
# ...

# %%
ds.synthesize()
# Out:
# We will synthesize 2430 entries of data
# Each entry may contain numerous time points
# 100%|█████████████████████████████████████| 2430/2430 [00:01<00:00, 1618.24it/s]

# %%
ds.export()
# Out:
# Written: /data1/projects/Heat/synthesized/2_heat_cognitive_pgng_summary_long_synthesized.csv

# %%
import importlib
import datasynthesis
importlib.reload(datasynthesis)
from datasynthesis import DataSynthesis

# %%
ds = DataSynthesis()

ds.load('/data1/projects/Heat/5_Cognitive/3_ER-40/3_heat_cognitive_er40_summary_long.csv',
        participantid='participant_id',
        data='value',
        type='variable',
        unit='unit',
        cols_to_keep=None,
        session='period',
        time_value=None,
        time_unit=None,
)

ds.checkit()
# Out:
# There are 27 participants in this data sheet
# 	H001
# 	H002
# 	H003
# 	H004
# 	H005
# 	H006
# 	H007
# 	H008
# 	H009
# 	H010
# 	H011
# 	H012
# 	H013
# 	H014
# 	H015
# 	H016
# 	H017
# 	H018
# 	H019
# 	H020
# 	H021
# 	H022
# 	H023
# 	H024
# 	H025
# 	H026
# 	H105
# There are 5 sessions in this data sheet
# 	Baseline
# 	Pre2h
# 	PostStress1
# 	PostStress2
# 	Post24h
# There are the following variables and units:
# 	computer.platform -- in units: category
# 	groupid -- in units: category
# 	elapsedtime -- in units: ms
# 	completed -- in units: category
# 	propCorrect -- in units: proportion
# 	countCorrect -- in units: count
# 	meanRT -- in units: ms
# 	meanCorrRT -- in units: ms
# 	medianRT -- in units: ms
# 	medianCorrRT -- in units: ms

# %%
ds.synthesize()
# Out:
# We will synthesize 1350 entries of data
# Each entry may contain numerous time points
# 100%|█████████████████████████████████████| 1350/1350 [00:00<00:00, 2842.60it/s]

# %%
ds.export()
# Out:
# Written: /data1/projects/Heat/synthesized/3_heat_cognitive_er40_summary_long_synthesized.csv
