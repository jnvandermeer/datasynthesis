# %%
from types import SimpleNamespace

# %%
opts=SimpleNamespace(subject=None, data=None)

# %%
opts.subject

# %%
params = SimpleNamespace(
            subject = None
            data = None
            type = None
            unit = None
            cols_to_keep = None
            session = None
            time_value = None
            time_unit = None
        )
# Out:
#   Cell In[7], line 2
#     subject = None
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
params = SimpleNamespace(
            subject = None,
            data = None,
            type = None,
            unit = None,
            cols_to_keep = None,
            session = None,
            time_value = None,
            time_unit = None
        )

# %%
vars(params)['subject']

# %%
self.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 self.params
#
# NameError: name 'self' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
